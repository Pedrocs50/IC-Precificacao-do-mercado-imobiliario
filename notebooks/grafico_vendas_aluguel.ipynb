# %%
import sys
import os

# Caminho relativo da pasta 'src'
sys.path.append(os.path.abspath("../src"))

from leitor_csv import LeitorCsv
from analise_dados import AnaliseDados

leitor = LeitorCsv("../data/processed/Preço-venda-aluguel.csv")
df = leitor.ler()

df.head()

analise = AnaliseDados(df)
analise.criar_grafico("venda")
